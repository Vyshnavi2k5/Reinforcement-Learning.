# %% [markdown]
# <a href="https://colab.research.google.com/github/Vyshnavi2k5/Reinforcement-Learning./blob/main/Lab_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A – Machine Initialization

machines = ['A', 'B', 'C']

# Number of plays
N_play = 10

# Exploration probability
epsilon = 0.2


# Part B – Initialize N, R and Q tables

# N = Number of times each machine is selected
N = {
    'A': 0,
    'B': 0,
    'C': 0
}

# R = Store rewards received from each machine
R = {
    'A': [],
    'B': [],
    'C': []
}

# Q = Estimated value of each machine
Q = {
    'A': 0,
    'B': 0,
    'C': 0
}

total_reward = 0


# Part C, D and E – ε-Greedy Decision,
# Reward Collection and Q-Value Update

for play in range(1, N_play + 1):

    print("\n---------------------------")
    print("Play", play)
    print("---------------------------")

    # Generate random number between 0 and 1
    r = random.random()

    # ε-Greedy decision
    if r < epsilon:

        # Exploration
        selected_machine = random.choice(machines)

        print("Exploration")
        print("Random number =", round(r, 2))

    else:

        # Exploitation
        selected_machine = max(Q, key=Q.get)

        print("Exploitation")
        print("Random number =", round(r, 2))

    print("Play with machine", selected_machine)

    # Part D – Get reward from user
    reward = float(input("Enter reward: "))

    # Store reward
    R[selected_machine].append(reward)

    # Update participation count
    N[selected_machine] += 1

    # Part E – Incremental Sample Average Update
    Q[selected_machine] = Q[selected_machine] + (
        reward - Q[selected_machine]
    ) / N[selected_machine]

    # Add reward to total reward
    total_reward += reward

    # Display updated values
    print("\nUpdated Values")

    print("N =", N)
    print("Q =", Q)


# Part F – Display Final Results

print("\n================================")
print("FINAL RESULTS")
print("================================")

for machine in machines:

    print("\nMachine", machine)
    print("Participation Count N =", N[machine])
    print("Rewards R =", R[machine])
    print("Q Value =", round(Q[machine], 2))


print("\n================================")
print("Total Reward after 10 plays =", total_reward)
print("================================")
# Out:
# ---------------------------
# Play 1
# ---------------------------
# Exploitation
# Random number = 0.39
# Play with machine A
# Enter reward: 4
#
# Updated Values
# N = {'A': 1, 'B': 0, 'C': 0}
# Q = {'A': 4.0, 'B': 0, 'C': 0}
#
# ---------------------------
# Play 2
# ---------------------------
# Exploitation
# Random number = 0.68
# Play with machine A
# Enter reward: 5
#
# Updated Values
# N = {'A': 2, 'B': 0, 'C': 0}
# Q = {'A': 4.5, 'B': 0, 'C': 0}
#
# ---------------------------
# Play 3
# ---------------------------
# Exploitation
# Random number = 0.62
# Play with machine A
# Enter reward: 7
#
# Updated Values
# N = {'A': 3, 'B': 0, 'C': 0}
# Q = {'A': 5.333333333333333, 'B': 0, 'C': 0}
#
# ---------------------------
# Play 4
# ---------------------------
# Exploitation
# Random number = 0.21
# Play with machine A
# Enter reward: 2
#
# Updated Values
# N = {'A': 4, 'B': 0, 'C': 0}
# Q = {'A': 4.5, 'B': 0, 'C': 0}
#
# ---------------------------
# Play 5
# ...
